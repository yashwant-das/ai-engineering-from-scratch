# %% [markdown]
# <a href="https://colab.research.google.com/github/yashwant-das/ai-engineering-from-scratch/blob/main/google/colab/playground.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# zsh:1: command not found: nvidia-smi

# %%
import torch
import time

size = 5000

a_cpu = torch.randn(size, size)
b_cpu = torch.randn(size, size)

start = time.time()
c_cpu = a_cpu @ b_cpu
cpu_time = time.time() - start
print(f"CPU: {cpu_time:.3f}s")

if torch.cuda.is_available():
    a_gpu = a_cpu.to("cuda")
    b_gpu = b_cpu.to("cuda")

    torch.cuda.synchronize()
    start = time.time()
    c_gpu = a_gpu @ b_gpu
    torch.cuda.synchronize()
    gpu_time = time.time() - start
    print(f"GPU: {gpu_time:.3f}s")
    print(f"Speedup: {cpu_time / gpu_time:.0f}x")
# Out:
# CPU: 0.094s

# %% [markdown]
# # Torch

# %%
import torch

print(torch.cuda.get_device_name(0))
print(torch.cuda.is_available())

# %%
import numpy as np
data = np.random.randn(1000)
data.mean(), data.std()
# Out:
# (np.float64(-0.019780243633491332), np.float64(1.015512460329833))

# %%
# %timeit np.random.randn(10000)
# Out:
# 88.5 μs ± 211 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %%time
model.fit(X_train, y_train, epochs=10)

# %%
# %matplotlib inline

# %%
import sys
print(sys.executable)
# Out:
# /Users/yash/Workspace/GitHub/ai-engineering-from-scratch/.venv/bin/python

# %%
# !uv pip list | grep scikit-learn
# Out:
# Using Python 3.12.11 environment at: /Users/yash/Workspace/GitHub/ai-engineering-from-scratch/.venv
# scikit-learn              1.8.0

# %%
import pandas as pd

df = pd.DataFrame({
    "model": ["Linear", "Random Forest", "Neural Net"],
    "accuracy": [0.72, 0.89, 0.94],
    "training_time": [0.1, 2.3, 45.6]
})
df
# Out:
#            model  accuracy  training_time
# 0         Linear      0.72            0.1
# 1  Random Forest      0.89            2.3
# 2     Neural Net      0.94           45.6

# %%
from IPython.display import Image, display
display(Image(filename="google_colab.png"))
